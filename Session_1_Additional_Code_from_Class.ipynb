# %%
round(  45123.673453546578,
        ndigits = 2       )

# %%
# putting units in thousands
int( round(  45123.673453546578,
             ndigits = -3      ) )

# %% [markdown]
# <br>

# %%
print(f"""
Total Charge Time Needed:
{round((charge_time * 60) * (est_vacuum_time / usable_time) // 60)} hours and {round((charge_time * 60) * (est_vacuum_time / usable_time) %  60)} minutes""")
