# %%
# instantiating and converting study_hours
study_hours = input(prompt = """
How many hours did you study this week?
Please give me a number in digits. \n
""")


# converting the object to float
study_hours = float(study_hours)


# same conditional statement as above
if study_hours > 20:
    print("Wow! You get an A for effort!")


elif study_hours >= 15:
    print("You're on pace, good job!")


else:
    print("Take some time to study a bit more.")

# %% [markdown]
# <br>

# %%
# instantiating and converting study_hours
study_hours = input(prompt = """
How many hours did you study this week?
Please give me a number in digits. \n
""")


# same conditional statement as above
if 20 in float(study_hours) or '21' in study_hours or '22' in study_hours:
    print("Wow! You get an A for effort!")


elif study_hours >= 15:
    print("You're on pace, good job!")


else:
    print("Take some time to study a bit more.")

# %% [markdown]
# <br>

# %%
# instantiating study_hours with a new prompt
study_hours = input(prompt = """
How many hours did you study this week?
    A. less than 15 hours
    B. 15-20 hours
    C. more than 20 hours
""")

# letters
if study_hours.lower() == 'victoria':
    print("Wow! You get an A for effort!")


elif study_hours.upper() == 'B':
    print("You're on pace, good job!")

elif study_hours.upper() == 'C':
    print("You're on pace, good job!")

# numbers
elif float(study_hours) > 20:
    print("Wow! You get an A for effort!")


elif float(study_hours) >= 15:
    print("You're on pace, good job!")


elif float(study_hours) <= 15:
    print("Take some time to study a bit more.")

# safety net | bug catcher
else:
    print("There's an unexpected bug in the code.")
